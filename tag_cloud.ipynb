# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahSouzaPontes/tag-cloud/blob/main/tag_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

def gerar_nuvem_etiquetas(texto):
    wordcloud = WordCloud(width=800, height=800, background_color='white', max_words=800).generate(texto)

    plt.figure(figsize=(8, 8), facecolor=None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad=0)

    plt.show()

def main():
    print("Bem-vindo(a) à ferramenta de geração de nuvem de etiquetas!")

    texto = input("Digite o texto para gerar a nuvem de etiquetas: ")

    gerar_nuvem_etiquetas(texto)

if __name__ == "__main__":
    main()
# Out:
# Bem-vindo(a) à ferramenta de geração de nuvem de etiquetas!
# Digite o texto para gerar a nuvem de etiquetas: Estamos procurando um especialista em gerenciamento de dados do Excel para criar uma pasta de trabalho simplificada para rastrear faturas complexas de fornecedores, pedidos de compra (POs) e um painel esclarecedor de alto nível. Este projeto requer experiência em funções do Excel, visualização de dados e grande atenção aos detalhes.  - Desenvolva uma pasta de trabalho abrangente em Excel para rastrear faturas de fornecedores e pedidos de compra correspondentes. - A planilha deve ser fácil de usar e permitir que nosso administrador organize e insira dados, garantindo precisão e integridade dos dados. - Crie um dashboard de alto nível utilizando as ferramentas de visualização de dados do Excel. - Resuma e exiba as principais métricas para obter insights de gerenciamento. - Permitir que nossa equipe colabore com outras equipes para rastrear e verificar faturas/pagamentos feitos ou não em várias organizações e dados de pedidos de compra. - Precisamos desta planilha para manter a consistência e melhorar a precisão dos dados por meio da validação. - Também exigiríamos que você fornecesse orientação sobre entrada de dados e melhores práticas.  Este seria um projeto único, mas poderia se transformar em trabalho adicional no futuro. Também exigiríamos que você assinasse um NDA, pois esta informação é estritamente confidencial.

# %%
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Lista de conectivos a serem excluídos
conectivos = [
    "primeiramente", "é", "de", "para", "e", "mas", "com", "em", "um", "m", "porém",
    "em primeiro lugar", "antes de mais nada", "antes de tudo",
    "acima de tudo", "para começar", "sobretudo", "principalmente", "outro", "outras", "ser", "deve", "o", "a", "os", "as", "à", "se","á", "ter", "tua", "sua", "seus", "" "nossa", "nisso", "so", "so", "pois", "que", "nao", "no", "na", "das", "dos", "de", "do", "da", "por", "isso", "esse", "isto", "este","primordialmente",
    # ... adicione os demais conectivos aqui
]

def remove_conectivos_isolados(texto):
    for conectivo in conectivos:
        # Usar expressão regular para encontrar o conectivo isolado
        pattern = r'\b' + re.escape(conectivo) + r'\b'
        texto = re.sub(pattern, "", texto, flags=re.IGNORECASE)
    return texto

def gerar_nuvem_etiquetas(texto):
    wordcloud = WordCloud(width=800, height=800, background_color='white', max_words=800).generate(texto)

    plt.figure(figsize=(8, 8), facecolor=None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad=0)

    plt.show()

def main():
    print("Bem-vindo(a) à ferramenta de geração de nuvem de etiquetas!")

    texto = input("Digite o texto para gerar a nuvem de etiquetas: ")

    texto_sem_conectivos = remove_conectivos_isolados(texto)
    gerar_nuvem_etiquetas(texto_sem_conectivos)

if __name__ == "__main__":
    main()
# Out:
# Bem-vindo(a) à ferramenta de geração de nuvem de etiquetas!
# Digite o texto para gerar a nuvem de etiquetas: Descrição Da Vaga  Estamos procurando um Desenvolvedor SQLServer Pl altamente motivado e experiente para se juntar à nossa empresa de tecnologia em crescimento. O candidato ideal deve ser capaz de trabalhar em equipe, ter habilidades sólidas de programação e estar familiarizado com as melhores práticas de desenvolvimento de software e otimização de Banco de Dados.  Responsabilidades  Desenvolvimento de Consultas SQL: Criação, manutenção e otimização de consultas em SQL Server para recuperação eficiente de dados.  Criação e Manutenção de Bancos de Dados: Implementar e manter bancos de dados SQL Server, garantindo segurança e desempenho.  Desenvolvimento de Relatórios em Power BI: Utilizar Power BI para criar relatórios visuais, dashboards e análises.  Integração de Dados: Trabalhar com ETL e outras técnicas de integração para combinar dados de várias fontes.  Colaboração com Equipes Ágeis: Trabalhar em colaboração com membros da equipe ágil, incluindo desenvolvedores, analistas
